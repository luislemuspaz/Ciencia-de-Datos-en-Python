# %% [markdown]
# # Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importar el archivo

# %%
fifa20 = pd.read_csv("players_20.csv")

# %% [markdown]
# ## Primeros registros

# %%
fifa20.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %% [markdown]
# ## Ùltimos registros

# %%
fifa20.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %% [markdown]
# ## Forma del archivo

# %%
fifa20.shape
# Out:
# (18278, 104)

# %% [markdown]
# ## Nombre de las columnas

# %%
fifa20.columns.values
# Out:
# array(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall',
#        'potential', 'value_eur', 'wage_eur', 'player_positions',
#        'preferred_foot', 'international_reputation', 'weak_foot',
#        'skill_moves', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes',
#        'gk_speed', 'gk_positioning', 'player_traits',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
# ...

# %% [markdown]
# ## Estadísticos básicos del dataset

# %%
fifa20.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %% [markdown]
# ## Tipo de dato para cada variable

# %%
fifa20.dtypes
# Out:
# sofifa_id                     int64
# player_url                   object
# short_name                   object
# long_name                    object
# age                           int64
# dob                          object
# height_cm                     int64
# weight_kg                     int64
# nationality                  object
# club                         object
# overall                       int64
# potential                     int64
# value_eur                     int64
# wage_eur                      int64
# player_positions             object
# preferred_foot               object
# international_reputation      int64
# weak_foot                     int64
# skill_moves                   int64
# work_rate                    object
# body_type                    object
# real_face                    object
# release_clause_eur          float64
# player_tags                  object
# team_position                object
# team_jersey_number          float64
# ...

# %%
fifa20_1 = fifa20[["short_name", "age", "height_cm", "weight_kg", "nationality", "club", "overall", "potential", "value_eur",
                 "wage_eur", "player_positions", "power_jumping", "power_long_shots"]]

# %%
fifa20_1.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   32        170         72   Argentina
# 1  Cristiano Ronaldo   34        187         83    Portugal
# 2          Neymar Jr   27        175         68      Brazil
# 3           J. Oblak   26        188         87    Slovenia
# 4          E. Hazard   28        175         74     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 2  Paris Saint-Germain       92         92  105500000    290000
# 3      Atlético Madrid       91         93   77500000    125000
# 4          Real Madrid       91         91   90000000    470000
#
#   player_positions  power_jumping  power_long_shots
# 0       RW, CF, ST             68                94
# 1           ST, LW             95                93
# 2          LW, CAM             61                84
# ...

# %%
type(fifa20_1)
# Out:
# pandas.core.frame.DataFrame

# %%
realmadrid = fifa20_1[fifa20_1["club"] == "Real Madrid"]
print(realmadrid.shape)
# Out:
# (33, 13)

# %%
realmadrid.head()
# Out:
#       short_name  age  height_cm  weight_kg nationality         club  overall  \
# 4      E. Hazard   28        175         74     Belgium  Real Madrid       91
# 8      L. Modrić   33        172         66     Croatia  Real Madrid       90
# 18  Sergio Ramos   33        184         82       Spain  Real Madrid       89
# 28   T. Courtois   27        199         96     Belgium  Real Madrid       88
# 36      T. Kroos   29        183         76     Germany  Real Madrid       88
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 8          90   45000000    340000               CM             68
# 18         89   31500000    300000               CB             93
# 28         89   48000000    235000               GK             68
# 36         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# 18                62
# ...

# %%
barcelona = fifa20_1[fifa20_1["club"] == "FC Barcelona"]
print(barcelona.shape)
# Out:
# (33, 13)

# %%
barcelona.head()
# Out:
#          short_name  age  height_cm  weight_kg nationality          club  \
# 0          L. Messi   32        170         72   Argentina  FC Barcelona
# 6     M. ter Stegen   27        187         85     Germany  FC Barcelona
# 19        L. Suárez   32        182         86     Uruguay  FC Barcelona
# 21  Sergio Busquets   30        189         76       Spain  FC Barcelona
# 22     A. Griezmann   28        176         73      France  FC Barcelona
#
#     overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 0        94         94   95500000    565000       RW, CF, ST             68
# 6        90         93   67500000    250000               GK             79
# 19       89         89   53000000    355000               ST             69
# 21       89         89   55000000    300000          CDM, CM             66
# 22       89         89   69000000    370000       CF, ST, LW             89
#
#     power_long_shots
# 0                 94
# 6                 10
# ...

# %% [markdown]
# ## ¿Qué club tiene los mejores jugadores? Real Madrid vs Barcelona

# %%
plt.figure()

plt.subplot(121)
plt.boxplot(realmadrid["overall"])
plt.ylabel("Overall")
plt.title("Real Madrid")
plt.grid(True)

plt.subplot(122)
plt.boxplot(barcelona["overall"])
plt.title("Barcelona")
plt.grid(True)

# %%
print(realmadrid["overall"].describe())
print(barcelona["overall"].describe())
# Out:
# count    33.000000
# mean     80.121212
# std       7.975578
# min      62.000000
# 25%      76.000000
# 50%      82.000000
# 75%      86.000000
# max      91.000000
# Name: overall, dtype: float64
# count    33.000000
# mean     78.363636
# std       9.370226
# min      64.000000
# 25%      70.000000
# 50%      82.000000
# 75%      86.000000
# max      94.000000
# Name: overall, dtype: float64

# %% [markdown]
# ## ¿Qué club tiene los jugadores mejor valorados? Real Madrid vs Barcelona

# %%
realmadrid["value_eur"].describe()
# Out:
# count    3.300000e+01
# mean     2.720758e+07
# std      2.063137e+07
# min      5.500000e+05
# 25%      1.300000e+07
# 50%      2.300000e+07
# 75%      4.050000e+07
# max      9.000000e+07
# Name: value_eur, dtype: float64

# %%
plt.hist(realmadrid["value_eur"])
plt.xlabel("Valor en 10x8 de millones de Euros")
plt.ylabel("Frecuencia")
plt.title("Valor en 10x8 de millones de Euros - Real Madrid")
# Out:
# Text(0.5, 1.0, 'Valor en 10x8 de millones de Euros - Real Madrid')

# %%
barcelona["value_eur"].describe()
# Out:
# count    3.300000e+01
# mean     2.634242e+07
# std      2.513480e+07
# min      8.500000e+05
# 25%      3.100000e+06
# 50%      2.200000e+07
# 75%      4.250000e+07
# max      9.550000e+07
# Name: value_eur, dtype: float64

# %%
plt.hist(barcelona["value_eur"])
plt.xlabel("Valor en 10x8 de millones de Euros")
plt.ylabel("Frecuencia")
plt.title("Valor en 10x8 de millones de Euros - Barcelona")
# Out:
# Text(0.5, 1.0, 'Valor en 10x8 de millones de Euros - Barcelona')

# %%
mostvalue_rm = realmadrid[realmadrid["value_eur"] > 50000000]
mostvalue_rm
# Out:
#    short_name  age  height_cm  weight_kg nationality         club  overall  \
# 4   E. Hazard   28        175         74     Belgium  Real Madrid       91
# 36   T. Kroos   29        183         76     Germany  Real Madrid       88
# 42   Casemiro   27        185         84      Brazil  Real Madrid       87
# 62       Isco   27        176         79       Spain  Real Madrid       86
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 36         88   57000000    330000               CM             30
# 42         89   53500000    240000              CDM             87
# 62         87   51000000    245000      CAM, CM, LW             61
#
#     power_long_shots
# 4                 80
# 36                86
# 42                81
# 62                84

# %%
mostvalue_bz = barcelona[barcelona["value_eur"] > 50000000]
mostvalue_bz
# Out:
#          short_name  age  height_cm  weight_kg  nationality          club  \
# 0          L. Messi   32        170         72    Argentina  FC Barcelona
# 6     M. ter Stegen   27        187         85      Germany  FC Barcelona
# 19        L. Suárez   32        182         86      Uruguay  FC Barcelona
# 21  Sergio Busquets   30        189         76        Spain  FC Barcelona
# 22     A. Griezmann   28        176         73       France  FC Barcelona
# 75       F. de Jong   22        180         74  Netherlands  FC Barcelona
#
#     overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 0        94         94   95500000    565000       RW, CF, ST             68
# 6        90         93   67500000    250000               GK             79
# 19       89         89   53000000    355000               ST             69
# 21       89         89   55000000    300000          CDM, CM             66
# ...

# %% [markdown]
# ## Relación de edades y valoraciones en 10x8 de millones de euros

# %%
fifa20_1.plot(kind = "scatter", x = "age", y = "value_eur")

# %% [markdown]
# ## Jugadores más valiosos

# %%
fifa20_1.describe()
# Out:
#                 age     height_cm     weight_kg       overall     potential  \
# count  18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean      25.283291    181.362184     75.276343     66.244994     71.546887
# std        4.656964      6.756961      7.047744      6.949953      6.139669
# min       16.000000    156.000000     50.000000     48.000000     49.000000
# 25%       22.000000    177.000000     70.000000     62.000000     67.000000
# 50%       25.000000    181.000000     75.000000     66.000000     71.000000
# 75%       29.000000    186.000000     80.000000     71.000000     75.000000
# max       42.000000    205.000000    110.000000     94.000000     95.000000
#
#           value_eur       wage_eur  power_jumping  power_long_shots
# count  1.827800e+04   18278.000000   18278.000000      18278.000000
# mean   2.484038e+06    9456.942773      64.928165         46.812945
# std    5.585481e+06   21351.714095      11.934059         19.322343
# ...

# %%
mostvalue_world = fifa20_1[fifa20_1["value_eur"] > 80000000]
print(fifa20_1.shape)
print(mostvalue_world.shape)
mostvalue_world
# Out:
# (18278, 13)
# (7, 13)
#       short_name  age  height_cm  weight_kg nationality                 club  \
# 0       L. Messi   32        170         72   Argentina         FC Barcelona
# 2      Neymar Jr   27        175         68      Brazil  Paris Saint-Germain
# 4      E. Hazard   28        175         74     Belgium          Real Madrid
# 5   K. De Bruyne   28        181         70     Belgium      Manchester City
# 9       M. Salah   27        175         71       Egypt            Liverpool
# 10     K. Mbappé   20        178         73      France  Paris Saint-Germain
# 12       H. Kane   25        188         89     England    Tottenham Hotspur
#
#     overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 0        94         94   95500000    565000       RW, CF, ST             68
# 2        92         92  105500000    290000          LW, CAM             61
# 4        91         91   90000000    470000           LW, CF             56
# ...

# %% [markdown]
# ## ¿Qué club tiene los jugadores con mejores salarios? Real Madrid vs Barcelona

# %%
realmadrid["wage_eur"].describe()
# Out:
# count        33.000000
# mean     162242.424242
# std      111794.462716
# min        6000.000000
# 25%       60000.000000
# 50%      165000.000000
# 75%      235000.000000
# max      470000.000000
# Name: wage_eur, dtype: float64

# %%
barcelona["wage_eur"].describe()
# Out:
# count        33.000000
# mean     150000.000000
# std      130914.810087
# min       12000.000000
# 25%       29000.000000
# 50%      155000.000000
# 75%      210000.000000
# max      565000.000000
# Name: wage_eur, dtype: float64

# %%
best_wage_rm = realmadrid[realmadrid["wage_eur"] > 300000]
best_wage_rm
# Out:
#    short_name  age  height_cm  weight_kg nationality         club  overall  \
# 4   E. Hazard   28        175         74     Belgium  Real Madrid       91
# 8   L. Modrić   33        172         66     Croatia  Real Madrid       90
# 36   T. Kroos   29        183         76     Germany  Real Madrid       88
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 8          90   45000000    340000               CM             68
# 36         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# 36                86

# %%
best_wage_bz = barcelona[barcelona["wage_eur"] > 300000]
best_wage_bz
# Out:
#       short_name  age  height_cm  weight_kg nationality          club  \
# 0       L. Messi   32        170         72   Argentina  FC Barcelona
# 19     L. Suárez   32        182         86     Uruguay  FC Barcelona
# 22  A. Griezmann   28        176         73      France  FC Barcelona
#
#     overall  potential  value_eur  wage_eur player_positions  power_jumping  \
# 0        94         94   95500000    565000       RW, CF, ST             68
# 19       89         89   53000000    355000               ST             69
# 22       89         89   69000000    370000       CF, ST, LW             89
#
#     power_long_shots
# 0                 94
# 19                86
# 22                83

# %% [markdown]
# ## ¿Qué jugador tiene los mejores salarios de FIFA 20?

# %%
fifa20_1["wage_eur"].describe()
# Out:
# count     18278.000000
# mean       9456.942773
# std       21351.714095
# min           0.000000
# 25%        1000.000000
# 50%        3000.000000
# 75%        8000.000000
# max      565000.000000
# Name: wage_eur, dtype: float64

# %%
best_wage_world = fifa20_1[fifa20_1["wage_eur"] > 250000]
best_wage_world
# Out:
#            short_name  age  height_cm  weight_kg nationality  \
# 0            L. Messi   32        170         72   Argentina
# 1   Cristiano Ronaldo   34        187         83    Portugal
# 2           Neymar Jr   27        175         68      Brazil
# 4           E. Hazard   28        175         74     Belgium
# 5        K. De Bruyne   28        181         70     Belgium
# 8           L. Modrić   33        172         66     Croatia
# 17          S. Agüero   31        173         70   Argentina
# 18       Sergio Ramos   33        184         82       Spain
# 19          L. Suárez   32        182         86     Uruguay
# 21    Sergio Busquets   30        189         76       Spain
# 22       A. Griezmann   28        176         73      France
# 26        R. Sterling   24        170         69     England
# 29              Piqué   32        194         85       Spain
# 33        David Silva   33        173         67       Spain
# ...

# %% [markdown]
# ## Potencia en tiros largos

# %%
plt.hist(fifa20_1["power_long_shots"])
plt.xlabel("Potencia en Tiros Largos")
plt.ylabel("Frecuencia")
plt.title("Potencia en Tiros Largos")
# Out:
# Text(0.5, 1.0, 'Potencia en Tiros Largos')

# %%
fifa20_1["power_long_shots"].describe()
# Out:
# count    18278.000000
# mean        46.812945
# std         19.322343
# min          4.000000
# 25%         32.000000
# 50%         51.000000
# 75%         62.000000
# max         94.000000
# Name: power_long_shots, dtype: float64

# %%
best_powershots = fifa20_1[fifa20_1["power_long_shots"] > 89]
best_powershots
# Out:
#             short_name  age  height_cm  weight_kg     nationality  \
# 0             L. Messi   32        170         72       Argentina
# 1    Cristiano Ronaldo   34        187         83        Portugal
# 5         K. De Bruyne   28        181         70         Belgium
# 43              H. Son   26        183         78  Korea Republic
# 100            G. Bale   29        185         82           Wales
# 106       J. Rodríguez   27        180         75        Colombia
# 532               Hulk   32        179         92          Brazil
#
#                   club  overall  potential  value_eur  wage_eur  \
# 0         FC Barcelona       94         94   95500000    565000
# 1             Juventus       93         93   58500000    405000
# 5      Manchester City       91         91   90000000    370000
# 43   Tottenham Hotspur       87         88   60000000    185000
# 100        Real Madrid       85         85   37500000    250000
# ...

# %% [markdown]
# ## Potencia en el Salto

# %%
plt.hist(fifa20_1["power_jumping"])
plt.xlabel("Potencia en Salto")
plt.ylabel("Frecuencia")
plt.title("Potencia en Salto")
# Out:
# Text(0.5, 1.0, 'Potencia en Salto')

# %%
fifa20_1["power_jumping"].describe()
# Out:
# count    18278.000000
# mean        64.928165
# std         11.934059
# min         19.000000
# 25%         58.000000
# 50%         66.000000
# 75%         73.000000
# max         95.000000
# Name: power_jumping, dtype: float64

# %%
best_powerjumping = fifa20_1[fifa20_1["power_jumping"] > 92]
best_powerjumping
# Out:
#               short_name  age  height_cm  weight_kg          nationality  \
# 1      Cristiano Ronaldo   34        187         83             Portugal
# 18          Sergio Ramos   33        184         82                Spain
# 93             M. Icardi   26        181         75            Argentina
# 1021          E. Boateng   23        175         70                Ghana
# 1659           E. Dennis   21        175         66              Nigeria
# 1792        Clinton Mata   26        180         73               Angola
# 2095           Zainadine   31        178         70           Mozambique
# 2410             S. Long   32        178         70  Republic of Ireland
# 2814         C. Paterson   24        187         76             Scotland
# 3596          O. Lewicki   26        171         68               Sweden
# 3693          G. Pazzini   34        180         78                Italy
# 4204         M. Barbieri   25        181         79            Argentina
# ...

# %% [markdown]
# ## Jugadores con mayor edad

# %%
fifa20_1["age"].describe()
# Out:
# count    18278.000000
# mean        25.283291
# std          4.656964
# min         16.000000
# 25%         22.000000
# 50%         25.000000
# 75%         29.000000
# max         42.000000
# Name: age, dtype: float64

# %%
age_old = fifa20_1[fifa20_1["age"] > 40]
age_old
# Out:
#          short_name  age  height_cm  weight_kg   nationality  \
# 200       G. Buffon   41        192         92         Italy
# 868          Hilton   41        180         78        Brazil
# 3706   C. Lucchetti   41        182         69     Argentina
# 10665      F. Kippe   41        194         97        Norway
# 11832      C. Muñoz   42        177         73     Argentina
# 13003  H. Sulaimani   42        173         70  Saudi Arabia
#
#                                club  overall  potential  value_eur  wage_eur  \
# 200                        Juventus       83         83    2600000     58000
# 868                 Montpellier HSC       78         78          0     21000
# 3706               Atlético Tucumán       72         72     325000      5000
# 10665                 Lillestrøm SK       65         65          0      1000
# 11832  CD Universidad de Concepción       64         64      50000      1000
# ...

# %% [markdown]
# ## Relación de Variables

# %%
fifa20_2 = fifa20[["age", "height_cm", "weight_kg", "overall", "potential", "value_eur",
                 "wage_eur", "power_jumping", "power_long_shots", "skill_moves", "shooting", "passing", "dribbling",
                 "defending", "physic", "movement_acceleration", "movement_agility", "mentality_vision"]]

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = fifa20_2.corr()
sns.heatmap(corr)

# %%
fifa20_2.plot(kind = "scatter", x = "mentality_vision", y = "passing", color = "orange")

# %%
fifa20_2.plot(kind = "scatter", x = "mentality_vision", y = "dribbling", color = "green")

# %%
fifa20_2.plot(kind = "scatter", x = "mentality_vision", y = "shooting", color = "red")

# %%
fifa20_2.plot(kind = "scatter", x = "height_cm", y = "movement_agility", color = "purple")

# %% [markdown]
# ## Ejercicios

# %%
realmadrid.head(5)
# Out:
#       short_name  age  height_cm  weight_kg nationality         club  overall  \
# 4      E. Hazard   28        175         74     Belgium  Real Madrid       91
# 8      L. Modrić   33        172         66     Croatia  Real Madrid       90
# 18  Sergio Ramos   33        184         82       Spain  Real Madrid       89
# 28   T. Courtois   27        199         96     Belgium  Real Madrid       88
# 36      T. Kroos   29        183         76     Germany  Real Madrid       88
#
#     potential  value_eur  wage_eur player_positions  power_jumping  \
# 4          91   90000000    470000           LW, CF             56
# 8          90   45000000    340000               CM             68
# 18         89   31500000    300000               CB             93
# 28         89   48000000    235000               GK             68
# 36         88   57000000    330000               CM             30
#
#     power_long_shots
# 4                 80
# 8                 82
# 18                62
# ...

# %%
realmadrid.iloc[:,0:4]
# Out:
#             short_name  age  height_cm  weight_kg
# 4            E. Hazard   28        175         74
# 8            L. Modrić   33        172         66
# 18        Sergio Ramos   33        184         82
# 28         T. Courtois   27        199         96
# 36            T. Kroos   29        183         76
# 42            Casemiro   27        185         84
# 46          K. Benzema   31        185         81
# 53            K. Navas   32        185         80
# 62                Isco   27        176         79
# 76           R. Varane   26        191         81
# 94            Carvajal   27        173         73
# 100            G. Bale   29        185         82
# 101            Marcelo   31        174         75
# 106       J. Rodríguez   27        180         75
# 161           L. Jović   21        182         85
# 178      Marco Asensio   23        182         76
# 277    Nacho Fernández   29        180         76
# 332       Éder Militão   21        186         78
# ...
