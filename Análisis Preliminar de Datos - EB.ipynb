# %%
import pandas as pd
import numpy as np

# %%
dfhr = pd.read_csv(filepath_or_buffer = "/Users/lalemus/Desktop/Escuela de Bayes/Business Analytics/Recursos Humanos/HRDataset_v13.csv")

# %%
dfhr.shape
# Out:
# (401, 35)

# %%
dfhr.dtypes
# Out:
# Employee_Name                  object
# EmpID                         float64
# MarriedID                     float64
# MaritalStatusID               float64
# GenderID                      float64
# EmpStatusID                   float64
# DeptID                        float64
# PerfScoreID                   float64
# FromDiversityJobFairID        float64
# PayRate                       float64
# Termd                         float64
# PositionID                    float64
# Position                       object
# State                          object
# Zip                           float64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
dfhr.head(10)
# Out:
#           Employee_Name         EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0            Brown, Mia  1.103024e+09        1.0              1.0       0.0
# 1  LaRotonda, William    1.106027e+09        0.0              2.0       1.0
# 2      Steans, Tyrone    1.302053e+09        0.0              0.0       1.0
# 3       Howard, Estelle  1.211051e+09        1.0              1.0       0.0
# 4           Singh, Nan   1.307060e+09        0.0              0.0       0.0
# 5      Smith, Leigh Ann  7.110077e+08        1.0              1.0       0.0
# 6      Bunbury, Jessica  1.504073e+09        1.0              1.0       0.0
# 7     Carter, Michelle   1.403066e+09        0.0              0.0       0.0
# 8     Dietrich, Jenna    1.408069e+09        0.0              0.0       0.0
# 9      Digitale, Alfred  1.306059e+09        1.0              1.0       1.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  \
# ...

# %%
dfhr.tail(5)
# Out:
#     Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 396           NaN    NaN        NaN              NaN       NaN          NaN
# 397           NaN    NaN        NaN              NaN       NaN          NaN
# 398           NaN    NaN        NaN              NaN       NaN          NaN
# 399           NaN    NaN        NaN              NaN       NaN          NaN
# 400           NaN    NaN        NaN              NaN       NaN          NaN
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  ...  Department  \
# 396     NaN          NaN                     NaN      NaN  ...         NaN
# 397     NaN          NaN                     NaN      NaN  ...         NaN
# 398     NaN          NaN                     NaN      NaN  ...         NaN
# 399     NaN          NaN                     NaN      NaN  ...         NaN
# 400     NaN          NaN                     NaN      NaN  ...         NaN
#
# ...

# %%
dfhr1 = dfhr[["Employee_Name","PayRate","Position","State","Sex","DOB","MaritalDesc","CitizenDesc","Department",
             "PerformanceScore","EngagementSurvey","EmpSatisfaction"]]

# %%
dfhr1.head(10)
# Out:
#           Employee_Name  PayRate                  Position State Sex  \
# 0            Brown, Mia    28.50              Accountant I    MA   F
# 1  LaRotonda, William      23.00              Accountant I    MA  M
# 2      Steans, Tyrone      29.00              Accountant I    MA  M
# 3       Howard, Estelle    21.50  Administrative Assistant    MA   F
# 4           Singh, Nan     16.56  Administrative Assistant    MA   F
# 5      Smith, Leigh Ann    20.50  Administrative Assistant    MA   F
# 6      Bunbury, Jessica    55.00        Area Sales Manager    VA   F
# 7     Carter, Michelle     55.00        Area Sales Manager    VT   F
# 8     Dietrich, Jenna      55.00        Area Sales Manager    WA   F
# 9      Digitale, Alfred    56.00        Area Sales Manager    NH  M
#
#         DOB MaritalDesc          CitizenDesc     Department PerformanceScore  \
# 0  11/24/87     Married           US Citizen  Admin Offices      Fully Meets
# ...
